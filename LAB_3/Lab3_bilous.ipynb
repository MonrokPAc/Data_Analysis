# %%
import re
import seaborn as sns
import pandas as pd
import numpy as np
from PIL import Image
import string, os, random
import matplotlib.pyplot as plt
pd.plotting.register_matplotlib_converters()
import cv2
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn. metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Conv2D, MaxPool2D, GlobalAveragePooling2D, Embedding, LSTM
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize


# Завантаження датасету
file_path = 'cancer issue.csv'
data = pd.read_csv(file_path)
# Копія оригінального датасету для обробки
df = data.copy()
# Кодування категоріальних даних
categorical_columns = ['Gender', 'Race/Ethnicity', 'SmokingStatus', 'FamilyHistory', 
                       'CancerType', 'Stage', 'TreatmentType', 'TreatmentResponse', 
                       'Recurrence', 'GeneticMarker', 'HospitalRegion']
label_encoders = {}
for column in categorical_columns:
    label_encoders[column] = LabelEncoder()
    df[column] = label_encoders[column].fit_transform(df[column])
# Нормалізація числових даних
numerical_columns = ['Age', 'BMI', 'TumorSize', 'SurvivalMonths']
scaler = MinMaxScaler()
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])
# Виведення перших рядків обробленого датасету
#print(df.head())

# Поділ даних на ознаки та цільову змінну
X = df.drop('SurvivalMonths', axis=1)  # Замініть «SurvivalMonths» на цільовий стовпець, якщо інший
y = df['SurvivalMonths']
# Поділ на навчальну і тестову вибірки
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4224)
y_train = keras.utils.to_categorical(y_train, len(y.unique()))
y_test = keras.utils.to_categorical(y_test, len(y.unique()))
# Побудова моделі
model = keras.Sequential([
    keras.layers.Input(shape=(X_train.shape[1],)), 
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(y_train.shape[1], activation='softmax')
])
# Компіляція моделі
optimizer = Adam(learning_rate=0.000006)
model.compile(loss="categorical_crossentropy", metrics=['accuracy'], optimizer=optimizer)
# Навчання моделі
history1 = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50)
# Виведення структури моделі
model.summary()
results = model.evaluate(X_test, y_test, verbose=0)
print('Losses:', results[0])
print('Accuracy:', results[1])
# Візуалізація результатів навчання
plt.figure(figsize=(6, 3))
plt.plot(history1.history['loss'], label='Losses')
plt.plot(history1.history['accuracy'], label='Accuracy')
plt.legend(loc='upper right')
plt.title('Training Loss and Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.show()

path = 'PetImages/'
categories = ['Cat', 'Dog']
# Читання та обробка зображень з обмеженням на 50 фотографій
x, y = [], []
for n, category in enumerate(categories):
    category_path = os.path.join(path, category)
    count = 0  # Счётчик фотографий
    for f in os.listdir(category_path):
        if count >= 1000:
            break
        image_path = os.path.join(category_path, f)
        image = cv2.imread(image_path)
        try:
            image = cv2.resize(image, (30, 50))
            image = image / 255.0
            x.append(image)
            y.append(n)
            count += 1
        except Exception as e:
            pass

# Поділ даних на навчальну і тестову вибірки
x_train, x_test, y_train, y_test = train_test_split(np.array(x), np.array(y), test_size=0.2)
y_train = tf.keras.utils.to_categorical(y_train, 2)
y_test = tf.keras.utils.to_categorical(y_test, 2)

print('x_train shape:', x_train.shape)
print('train number:', x_train.shape[0])
print('test number:', x_test.shape[0])

# Побудова моделі
model2 = Sequential([
    Input(shape=(50, 30, 3)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPool2D((2, 2)),
    GlobalAveragePooling2D(),
    Dense(128, activation='relu'),
    Dense(2, activation='softmax')
])
# Компіляція моделі
optimizer = Adam(learning_rate=0.009)
model2.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=optimizer)

# Навчання моделі
history2 = model2.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size=32, epochs=100)
# Оцінка моделі
results2 = model2.evaluate(x_test, y_test, verbose=0)
print('Losses:', results2[0])
print('Accuracy:', results2[1])

# Візуалізація результатів навчання
plt.figure(figsize=(6, 3))
plt.plot(history2.history['loss'], label='Losses')
plt.plot(history2.history['accuracy'], label='Accuracy')
plt.legend(bbox_to_anchor=(1, 1))
plt.title('Model Performance')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.show()


# Шлях до папки із зображеннями
path = 'PetImages/'
categories = ['Cat', 'Dog']

# Читання та обробка зображень з обмеженням на 50 фотографій
x, y = [], []

for n, category in enumerate(categories):
    category_path = os.path.join(path, category)
    count = 0  # Счётчик фотографий
    for f in os.listdir(category_path):
        if count >= 200:  # Ограничение на 50 фотографий
            break
        image_path = os.path.join(category_path, f)
        image = cv2.imread(image_path)
        try:
            image = cv2.resize(image, (224, 224))
            image = image / 255.0
            x.append(image)
            y.append(n)
            count += 1
        except Exception as e:
            pass

# Перетворення даних у масиви
x = np.array(x)
y = np.array(y)

# Поділ даних на навчальну і тестову вибірки
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Перетворення міток у формат one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train, num_classes=2)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=2)

# Завантаження переднавченої моделі MobileNetV2
base_model = tf.keras.applications.MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Заморожування ваг базової моделі
base_model.trainable = False

# Створення моделі з додатковими шарами
trans_model = Sequential([
    base_model, 
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(2, activation='softmax') 
])

# Компіляція моделі
trans_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
trans_model.summary()
# Навчання моделі
history = trans_model.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size=32, epochs=10)

# Оцінка моделі
results_t = trans_model.evaluate(x_test, y_test, verbose=0)
print('Losses:', results_t[0])
print('Accuracy:', results_t[1])

# Візуалізація результатів навчання
plt.figure(figsize=(6, 3))
plt.plot(history.history['loss'], label='Losses')
plt.plot(history.history['accuracy'], label='Accuracy')
plt.legend(bbox_to_anchor=(1, 1))
plt.title('Model Performance')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.show()


# Завантажте та очистіть набір даних
file_path = 'spam.csv'
spam_data = pd.read_csv(file_path, encoding='latin-1')

# Зберігайте лише релевантні стовпці
spam_data = spam_data[['v1', 'v2']]
spam_data.columns = ['Category', 'Message']

# Визначте функцію очищення
def cleaning(value):
    punctuation_cleaning = []
    stopwords_cleaning_string = ''
    
    for i in value:
        if i not in string.punctuation:
            punctuation_cleaning.append(i)
    punctuation_cleaning = "".join(punctuation_cleaning).split()
    
    for j in punctuation_cleaning:
        if j.lower() not in stopwords.words("english"):
            stopwords_cleaning_string += j.lower() + ' '
    
    return stopwords_cleaning_string

# Застосувати очищення до повідомлень
spam_data['Message'] = spam_data['Message'].apply(cleaning)

# Розділіть дані на функції та мітки
X = spam_data['Message']
y = spam_data['Category']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=123)

# Кодування міток
encoder = LabelEncoder()
y_train = encoder.fit_transform(y_train) 
y_test = encoder.transform(y_test)

# Токенізація та pad послідовності
token = Tokenizer(lower=False)
token.fit_on_texts(X_train)
X_train = token.texts_to_sequences(X_train)
X_test = token.texts_to_sequences(X_test)

# Визначити максимальну довжину послідовності
array = [len(i) for i in X_train]
maxlen = int(np.ceil(np.mean(array)))

# pad послідовності
X_train = pad_sequences(X_train, maxlen=maxlen)
X_test = pad_sequences(X_test, maxlen=maxlen)
total_words = len(token.word_index) + 1

# Побудуйте модель LSTM
model = Sequential([
    Embedding(total_words, 32, input_length=maxlen),
    LSTM(10),
    Dense(1, activation='sigmoid')
])

# Складіть модель
optimizer = Adam(learning_rate=0.0001)
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer=optimizer)

# Навчання модель
history = model.fit(X_train, y_train, epochs=20, batch_size=32)

# Оцінка моделі
results = model.evaluate(X_test, y_test, verbose=0)
print('Losses:', results[0])
print('Accuracy:', results[1])

# Візуалізація результатів навчання
plt.figure(figsize=(6, 3))
plt.plot(history.history['loss'])
plt.plot(history.history['accuracy'])
plt.legend(['Losses', 'Accuracy'], bbox_to_anchor=(1, 1))
plt.title('Model Performance')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.show()


# Завантажте та очистіть набір даних
file_path = 'spam.csv'
spam_data = pd.read_csv(file_path, encoding='latin-1')

# Зберігання лише релевантні стовпці
spam_data = spam_data[['v1', 'v2']]
spam_data.columns = ['Category', 'Message']

# Визначення функції очищення
def cleaning(value):
    punctuation_cleaning = []
    stopwords_cleaning_string = ''
    
    for i in value:
        if i not in string.punctuation:
            punctuation_cleaning.append(i)
    punctuation_cleaning = "".join(punctuation_cleaning).split()
    
    for j in punctuation_cleaning:
        if j.lower() not in stopwords.words("english"):
            stopwords_cleaning_string += j.lower() + ' '
    
    return stopwords_cleaning_string

# Застосування очищення до повідомлень
spam_data['Message'] = spam_data['Message'].apply(cleaning)

# Розділіть дані на функції та мітки
X = spam_data['Message']
y = spam_data['Category']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=123)

#Кодування міток
encoder = LabelEncoder()
y_train = encoder.fit_transform(y_train) 
y_test = encoder.transform(y_test)

# Токенізація та pad-послідовності
token = Tokenizer(lower=False)
token.fit_on_texts(X_train)
X_train = token.texts_to_sequences(X_train)
X_test = token.texts_to_sequences(X_test)

# Визначити максимальну довжину послідовності
array = [len(i) for i in X_train]
maxlen = int(np.ceil(np.mean(array)))

# pad-послідовності
X_train = pad_sequences(X_train, maxlen=maxlen)
X_test = pad_sequences(X_test, maxlen=maxlen)
total_words = len(token.word_index) + 1

# Завантаження GloVe embeddings
embedding_index = {}
embedding_dim = 50
with open('glove.6B.50d.txt', 'r', encoding='utf-8') as file:
    for line in file:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embedding_index[word] = coefs

# Створення матриці вбудовування
embedding_matrix = np.zeros((total_words, embedding_dim))
for word, i in token.word_index.items():
    if i >= total_words:
        continue
    embedding_vector = embedding_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# Побудування моделі
trans_model2 = Sequential([
    Embedding(total_words, embedding_dim, weights=[embedding_matrix], trainable=False),
    LSTM(10, dropout=0.2, recurrent_dropout=0.2, name="lstm_layer"),
    Dense(1, activation='sigmoid', name="output_layer")
])

# Складання моделі
trans_model2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Навчання модель
history_trans2 = trans_model2.fit(X_train, y_train, epochs=20, batch_size=64, validation_split=0.2, shuffle=True)

# Оцініка моделі
results3_t = trans_model2.evaluate(X_test, y_test, verbose=0)
print('Losses:', results3_t[0])
print('Accuracy:', results3_t[1])

# Візуалізація результатів навчання
plt.figure(figsize=(6, 3))
plt.plot(history_trans2.history['loss'], label='Losses')
plt.plot(history_trans2.history['accuracy'], label='Accuracy')
plt.legend(bbox_to_anchor=(1, 1))
plt.title('Model Performance')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.show()
# Out:
# Epoch 1/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0000e+00 - loss: 1592.2054 - val_accuracy: 0.0000e+00 - val_loss: 1465.6786
# Epoch 2/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 1457.1072 - val_accuracy: 0.0000e+00 - val_loss: 1337.4916
# Epoch 3/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 1333.9458 - val_accuracy: 0.0000e+00 - val_loss: 1214.3584
# Epoch 4/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 1199.0803 - val_accuracy: 0.0000e+00 - val_loss: 1096.2560
# Epoch 5/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 1080.5452 - val_accuracy: 0.0000e+00 - val_loss: 984.9597
# Epoch 6/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 976.4272 - val_accuracy: 0.0000e+00 - val_loss: 878.5962
# Epoch 7/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 867.1935 - val_accuracy: 0.0000e+00 - val_loss: 779.1874
# Epoch 8/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 771.0423 - val_accuracy: 0.0000e+00 - val_loss: 681.3725
# Epoch 9/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 667.6598 - val_accuracy: 0.0000e+00 - val_loss: 584.5370
# Epoch 10/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.0000e+00 - loss: 571.1554 - val_accuracy: 0.0000e+00 - val_loss: 488.5262
# Epoch 11/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 472.0366 - val_accuracy: 0.0000e+00 - val_loss: 392.9544
# Epoch 12/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 377.7187 - val_accuracy: 0.0000e+00 - val_loss: 297.3030
# Epoch 13/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0000e+00 - loss: 279.0865 - val_accuracy: 0.0000e+00 - val_loss: 201.5236
# Epoch 14/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 8.0116e-06 - loss: 182.3017 - val_accuracy: 2.8265e-04 - val_loss: 105.1715
# Epoch 15/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.0071 - loss: 81.4751 - val_accuracy: 0.9904 - val_loss: 17.6489
# Epoch 16/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9899 - loss: 15.7913 - val_accuracy: 0.9907 - val_loss: 17.4558
# Epoch 17/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9881 - loss: 18.6437 - val_accuracy: 0.9910 - val_loss: 17.2995
# Epoch 18/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9882 - loss: 15.3814 - val_accuracy: 0.9910 - val_loss: 17.1411
# Epoch 19/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9891 - loss: 18.5489 - val_accuracy: 0.9910 - val_loss: 16.9778
# Epoch 20/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9901 - loss: 16.3653 - val_accuracy: 0.9910 - val_loss: 16.8009
# Epoch 21/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9899 - loss: 16.1815 - val_accuracy: 0.9910 - val_loss: 16.6092
# Epoch 22/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9905 - loss: 15.9938 - val_accuracy: 0.9912 - val_loss: 16.4020
# Epoch 23/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9885 - loss: 19.9100 - val_accuracy: 0.9912 - val_loss: 16.1814
# Epoch 24/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9881 - loss: 17.4836 - val_accuracy: 0.9912 - val_loss: 15.9502
# Epoch 25/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9900 - loss: 14.6741 - val_accuracy: 0.9912 - val_loss: 15.6959
# Epoch 26/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9897 - loss: 16.0590 - val_accuracy: 0.9912 - val_loss: 15.4299
# Epoch 27/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9905 - loss: 14.7485 - val_accuracy: 0.9912 - val_loss: 15.1385
# Epoch 28/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9906 - loss: 15.9744 - val_accuracy: 0.9912 - val_loss: 14.8303
# Epoch 29/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9907 - loss: 13.6683 - val_accuracy: 0.9912 - val_loss: 14.5119
# Epoch 30/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9908 - loss: 13.1498 - val_accuracy: 0.9912 - val_loss: 14.1820
# Epoch 31/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9909 - loss: 12.5933 - val_accuracy: 0.9912 - val_loss: 13.8399
# Epoch 32/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9883 - loss: 15.5502 - val_accuracy: 0.9912 - val_loss: 13.4766
# Epoch 33/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9909 - loss: 12.7413 - val_accuracy: 0.9912 - val_loss: 13.1079
# Epoch 34/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9900 - loss: 13.2665 - val_accuracy: 0.9912 - val_loss: 12.7261
# Epoch 35/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9890 - loss: 14.9203 - val_accuracy: 0.9912 - val_loss: 12.3439
# Epoch 36/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9897 - loss: 13.8299 - val_accuracy: 0.9912 - val_loss: 11.9544
# Epoch 37/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9895 - loss: 12.2682 - val_accuracy: 0.9912 - val_loss: 11.5522
# Epoch 38/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9898 - loss: 12.3629 - val_accuracy: 0.9912 - val_loss: 11.1509
# Epoch 39/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9903 - loss: 11.0772 - val_accuracy: 0.9912 - val_loss: 10.7490
# Epoch 40/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9902 - loss: 11.3429 - val_accuracy: 0.9912 - val_loss: 10.3351
# Epoch 41/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9899 - loss: 11.1148 - val_accuracy: 0.9912 - val_loss: 9.9262
# Epoch 42/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9910 - loss: 9.2294 - val_accuracy: 0.9912 - val_loss: 9.5054
# Epoch 43/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9900 - loss: 9.8908 - val_accuracy: 0.9912 - val_loss: 9.0907
# Epoch 44/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9903 - loss: 8.9062 - val_accuracy: 0.9912 - val_loss: 8.7105
# Epoch 45/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9899 - loss: 9.0742 - val_accuracy: 0.9912 - val_loss: 8.3247
# Epoch 46/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 8.1070 - val_accuracy: 0.9912 - val_loss: 7.9387
# Epoch 47/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9908 - loss: 7.4765 - val_accuracy: 0.9912 - val_loss: 7.5581
# Epoch 48/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9897 - loss: 7.1202 - val_accuracy: 0.9912 - val_loss: 7.1683
# Epoch 49/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9910 - loss: 6.4929 - val_accuracy: 0.9912 - val_loss: 6.7965
# Epoch 50/50
# 443/443 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9905 - loss: 6.0143 - val_accuracy: 0.9912 - val_loss: 6.4287
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 32)                  │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 120)                 │           2,040 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9,242 (36.11 KB)
#  Trainable params: 3,080 (12.03 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 6,162 (24.07 KB)
# Losses: 6.428708553314209
# Accuracy: 0.991237998008728
# x_train shape: (1600, 50, 30, 3)
# train number: 1600
# test number: 400
# Epoch 1/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.4982 - loss: 0.7018 - val_accuracy: 0.5150 - val_loss: 0.6922
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5028 - loss: 0.6933 - val_accuracy: 0.4850 - val_loss: 0.6929
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4813 - loss: 0.6931 - val_accuracy: 0.4850 - val_loss: 0.6899
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5332 - loss: 0.6908 - val_accuracy: 0.5725 - val_loss: 0.6823
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5362 - loss: 0.6838 - val_accuracy: 0.5750 - val_loss: 0.6807
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5217 - loss: 0.6875 - val_accuracy: 0.5750 - val_loss: 0.6769
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5615 - loss: 0.6892 - val_accuracy: 0.5750 - val_loss: 0.6774
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5633 - loss: 0.6785 - val_accuracy: 0.4850 - val_loss: 0.6870
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5187 - loss: 0.6924 - val_accuracy: 0.5750 - val_loss: 0.6769
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5387 - loss: 0.6829 - val_accuracy: 0.6000 - val_loss: 0.6756
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5489 - loss: 0.6808 - val_accuracy: 0.5975 - val_loss: 0.6785
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5539 - loss: 0.6877 - val_accuracy: 0.5375 - val_loss: 0.6787
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5609 - loss: 0.6872 - val_accuracy: 0.5800 - val_loss: 0.6757
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5540 - loss: 0.6823 - val_accuracy: 0.5750 - val_loss: 0.6755
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5485 - loss: 0.6832 - val_accuracy: 0.5325 - val_loss: 0.6820
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5637 - loss: 0.6801 - val_accuracy: 0.5675 - val_loss: 0.6783
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5293 - loss: 0.6799 - val_accuracy: 0.5875 - val_loss: 0.6706
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5956 - loss: 0.6648 - val_accuracy: 0.4850 - val_loss: 0.6939
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5101 - loss: 0.6914 - val_accuracy: 0.5525 - val_loss: 0.6789
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5280 - loss: 0.6852 - val_accuracy: 0.5975 - val_loss: 0.6742
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5505 - loss: 0.6885 - val_accuracy: 0.5625 - val_loss: 0.6755
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5447 - loss: 0.6851 - val_accuracy: 0.5725 - val_loss: 0.6759
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5371 - loss: 0.6831 - val_accuracy: 0.5725 - val_loss: 0.6785
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5576 - loss: 0.6831 - val_accuracy: 0.5650 - val_loss: 0.6778
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5468 - loss: 0.6818 - val_accuracy: 0.5725 - val_loss: 0.6771
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5566 - loss: 0.6814 - val_accuracy: 0.5700 - val_loss: 0.6793
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5539 - loss: 0.6820 - val_accuracy: 0.5625 - val_loss: 0.6808
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5576 - loss: 0.6792 - val_accuracy: 0.5675 - val_loss: 0.6750
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5417 - loss: 0.6872 - val_accuracy: 0.4850 - val_loss: 0.6879
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5300 - loss: 0.6777 - val_accuracy: 0.5775 - val_loss: 0.6773
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5317 - loss: 0.6837 - val_accuracy: 0.5750 - val_loss: 0.6729
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5727 - loss: 0.6669 - val_accuracy: 0.5200 - val_loss: 0.6812
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5461 - loss: 0.6779 - val_accuracy: 0.6400 - val_loss: 0.6390
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6160 - loss: 0.6635 - val_accuracy: 0.5825 - val_loss: 0.6694
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5690 - loss: 0.6709 - val_accuracy: 0.6350 - val_loss: 0.6453
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6128 - loss: 0.6613 - val_accuracy: 0.6475 - val_loss: 0.6242
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5835 - loss: 0.6672 - val_accuracy: 0.6350 - val_loss: 0.6481
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6114 - loss: 0.6575 - val_accuracy: 0.6400 - val_loss: 0.6368
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6252 - loss: 0.6513 - val_accuracy: 0.6550 - val_loss: 0.6272
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6300 - loss: 0.6549 - val_accuracy: 0.6475 - val_loss: 0.6287
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6210 - loss: 0.6506 - val_accuracy: 0.6125 - val_loss: 0.6496
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6241 - loss: 0.6519 - val_accuracy: 0.5950 - val_loss: 0.6508
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6063 - loss: 0.6561 - val_accuracy: 0.6325 - val_loss: 0.6344
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6285 - loss: 0.6443 - val_accuracy: 0.6150 - val_loss: 0.6385
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6505 - loss: 0.6374 - val_accuracy: 0.6300 - val_loss: 0.6295
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6160 - loss: 0.6539 - val_accuracy: 0.6575 - val_loss: 0.6264
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6443 - loss: 0.6332 - val_accuracy: 0.6275 - val_loss: 0.6365
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6514 - loss: 0.6360 - val_accuracy: 0.6400 - val_loss: 0.6289
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6375 - loss: 0.6378 - val_accuracy: 0.6050 - val_loss: 0.6480
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6158 - loss: 0.6412 - val_accuracy: 0.6325 - val_loss: 0.6367
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6538 - loss: 0.6356 - val_accuracy: 0.6575 - val_loss: 0.6284
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6269 - loss: 0.6405 - val_accuracy: 0.6550 - val_loss: 0.6246
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6432 - loss: 0.6363 - val_accuracy: 0.6375 - val_loss: 0.6238
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6463 - loss: 0.6346 - val_accuracy: 0.6350 - val_loss: 0.6323
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6133 - loss: 0.6501 - val_accuracy: 0.6400 - val_loss: 0.6293
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6352 - loss: 0.6434 - val_accuracy: 0.6425 - val_loss: 0.6337
# Epoch 57/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6324 - loss: 0.6450 - val_accuracy: 0.6375 - val_loss: 0.6316
# Epoch 58/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6393 - loss: 0.6379 - val_accuracy: 0.6400 - val_loss: 0.6257
# Epoch 59/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6458 - loss: 0.6363 - val_accuracy: 0.6400 - val_loss: 0.6291
# Epoch 60/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6484 - loss: 0.6279 - val_accuracy: 0.6400 - val_loss: 0.6269
# Epoch 61/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6482 - loss: 0.6324 - val_accuracy: 0.6350 - val_loss: 0.6295
# Epoch 62/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6291 - loss: 0.6470 - val_accuracy: 0.6500 - val_loss: 0.6325
# Epoch 63/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6157 - loss: 0.6494 - val_accuracy: 0.6500 - val_loss: 0.6312
# Epoch 64/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6401 - loss: 0.6381 - val_accuracy: 0.6375 - val_loss: 0.6303
# Epoch 65/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6549 - loss: 0.6303 - val_accuracy: 0.6475 - val_loss: 0.6317
# Epoch 66/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6466 - loss: 0.6349 - val_accuracy: 0.6575 - val_loss: 0.6353
# Epoch 67/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6436 - loss: 0.6344 - val_accuracy: 0.6400 - val_loss: 0.6230
# Epoch 68/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6352 - loss: 0.6356 - val_accuracy: 0.6375 - val_loss: 0.6316
# Epoch 69/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6378 - loss: 0.6448 - val_accuracy: 0.6225 - val_loss: 0.6404
# Epoch 70/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6193 - loss: 0.6440 - val_accuracy: 0.6450 - val_loss: 0.6263
# Epoch 71/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6497 - loss: 0.6298 - val_accuracy: 0.6500 - val_loss: 0.6260
# Epoch 72/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6541 - loss: 0.6439 - val_accuracy: 0.6375 - val_loss: 0.6300
# Epoch 73/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6473 - loss: 0.6386 - val_accuracy: 0.6425 - val_loss: 0.6290
# Epoch 74/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6401 - loss: 0.6353 - val_accuracy: 0.6400 - val_loss: 0.6400
# Epoch 75/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6364 - loss: 0.6341 - val_accuracy: 0.6300 - val_loss: 0.6284
# Epoch 76/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6563 - loss: 0.6245 - val_accuracy: 0.6275 - val_loss: 0.6440
# Epoch 77/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6468 - loss: 0.6334 - val_accuracy: 0.6550 - val_loss: 0.6335
# Epoch 78/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6300 - loss: 0.6341 - val_accuracy: 0.6400 - val_loss: 0.6405
# Epoch 79/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6577 - loss: 0.6293 - val_accuracy: 0.6450 - val_loss: 0.6319
# Epoch 80/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6171 - loss: 0.6429 - val_accuracy: 0.6325 - val_loss: 0.6293
# Epoch 81/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6453 - loss: 0.6336 - val_accuracy: 0.6200 - val_loss: 0.6286
# Epoch 82/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6390 - loss: 0.6331 - val_accuracy: 0.6325 - val_loss: 0.6412
# Epoch 83/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6550 - loss: 0.6307 - val_accuracy: 0.6475 - val_loss: 0.6247
# Epoch 84/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6262 - loss: 0.6405 - val_accuracy: 0.6300 - val_loss: 0.6322
# Epoch 85/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6563 - loss: 0.6220 - val_accuracy: 0.6525 - val_loss: 0.6348
# Epoch 86/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6603 - loss: 0.6147 - val_accuracy: 0.6150 - val_loss: 0.6459
# Epoch 87/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6364 - loss: 0.6370 - val_accuracy: 0.6425 - val_loss: 0.6363
# Epoch 88/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6634 - loss: 0.6291 - val_accuracy: 0.6400 - val_loss: 0.6317
# Epoch 89/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6346 - loss: 0.6322 - val_accuracy: 0.6400 - val_loss: 0.6335
# Epoch 90/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6324 - loss: 0.6340 - val_accuracy: 0.6425 - val_loss: 0.6334
# Epoch 91/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6478 - loss: 0.6264 - val_accuracy: 0.6475 - val_loss: 0.6357
# Epoch 92/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6495 - loss: 0.6214 - val_accuracy: 0.6475 - val_loss: 0.6420
# Epoch 93/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6453 - loss: 0.6278 - val_accuracy: 0.6500 - val_loss: 0.6322
# Epoch 94/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6439 - loss: 0.6247 - val_accuracy: 0.6450 - val_loss: 0.6288
# Epoch 95/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6465 - loss: 0.6275 - val_accuracy: 0.6000 - val_loss: 0.6597
# Epoch 96/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6566 - loss: 0.6267 - val_accuracy: 0.6475 - val_loss: 0.6396
# Epoch 97/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6402 - loss: 0.6315 - val_accuracy: 0.6450 - val_loss: 0.6370
# Epoch 98/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6464 - loss: 0.6289 - val_accuracy: 0.6475 - val_loss: 0.6382
# Epoch 99/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6499 - loss: 0.6362 - val_accuracy: 0.6350 - val_loss: 0.6297
# Epoch 100/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6375 - loss: 0.6342 - val_accuracy: 0.6500 - val_loss: 0.6391
# Losses: 0.6391335129737854
# Accuracy: 0.6499999761581421
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224 (Functional)    │ (None, 7, 7, 1280)          │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 128)                 │         163,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 2)                   │             258 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,422,210 (9.24 MB)
#  Trainable params: 164,226 (641.51 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
# Epoch 1/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 488ms/step - accuracy: 0.7016 - loss: 0.5943 - val_accuracy: 0.9625 - val_loss: 0.1094
# Epoch 2/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 374ms/step - accuracy: 0.9726 - loss: 0.0840 - val_accuracy: 0.9750 - val_loss: 0.0947
# Epoch 3/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 368ms/step - accuracy: 0.9875 - loss: 0.0312 - val_accuracy: 0.9500 - val_loss: 0.0880
# Epoch 4/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 362ms/step - accuracy: 0.9876 - loss: 0.0258 - val_accuracy: 0.9625 - val_loss: 0.1046
# Epoch 5/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 377ms/step - accuracy: 0.9966 - loss: 0.0143 - val_accuracy: 0.9500 - val_loss: 0.1455
# Epoch 6/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 364ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.9500 - val_loss: 0.1386
# Epoch 7/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 383ms/step - accuracy: 0.9966 - loss: 0.0133 - val_accuracy: 0.9750 - val_loss: 0.0883
# Epoch 8/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 364ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9500 - val_loss: 0.1102
# Epoch 9/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 362ms/step - accuracy: 1.0000 - loss: 0.0036 - val_accuracy: 0.9500 - val_loss: 0.1206
# Epoch 10/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 4s 361ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.9500 - val_loss: 0.1258
# Losses: 0.12575916945934296
# Accuracy: 0.949999988079071
# Epoch 1/20
# C:\Users\dolba\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7368 - loss: 0.6822
# Epoch 2/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8582 - loss: 0.6207
# Epoch 3/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8619 - loss: 0.5253
# Epoch 4/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8600 - loss: 0.4279
# Epoch 5/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8577 - loss: 0.3702
# Epoch 6/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8589 - loss: 0.3330
# Epoch 7/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8737 - loss: 0.2903
# Epoch 8/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9036 - loss: 0.2443
# Epoch 9/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9214 - loss: 0.2267
# Epoch 10/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9395 - loss: 0.2075
# Epoch 11/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9452 - loss: 0.2013
# Epoch 12/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9609 - loss: 0.1704
# Epoch 13/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9672 - loss: 0.1755
# Epoch 14/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9745 - loss: 0.1509
# Epoch 15/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9745 - loss: 0.1568
# Epoch 16/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9817 - loss: 0.1372
# Epoch 17/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9856 - loss: 0.1215
# Epoch 18/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.1260
# Epoch 19/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9858 - loss: 0.1199
# Epoch 20/20
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9863 - loss: 0.1149
# Losses: 0.1402852088212967
# Accuracy: 0.9716439247131348
# Epoch 1/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7766 - loss: 0.6123 - val_accuracy: 0.8495 - val_loss: 0.4844
# Epoch 2/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8545 - loss: 0.4571 - val_accuracy: 0.8477 - val_loss: 0.4046
# Epoch 3/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8532 - loss: 0.3908 - val_accuracy: 0.8477 - val_loss: 0.3729
# Epoch 4/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8462 - loss: 0.3655 - val_accuracy: 0.8477 - val_loss: 0.3403
# Epoch 5/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8608 - loss: 0.3115 - val_accuracy: 0.8566 - val_loss: 0.2949
# Epoch 6/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8705 - loss: 0.2718 - val_accuracy: 0.8817 - val_loss: 0.2494
# Epoch 7/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9184 - loss: 0.2103 - val_accuracy: 0.9337 - val_loss: 0.2026
# Epoch 8/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9366 - loss: 0.2138 - val_accuracy: 0.9462 - val_loss: 0.1801
# Epoch 9/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9424 - loss: 0.1834 - val_accuracy: 0.9480 - val_loss: 0.1695
# Epoch 10/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9414 - loss: 0.1735 - val_accuracy: 0.9516 - val_loss: 0.1637
# Epoch 11/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9442 - loss: 0.1708 - val_accuracy: 0.9516 - val_loss: 0.1548
# Epoch 12/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9399 - loss: 0.1805 - val_accuracy: 0.9534 - val_loss: 0.1505
# Epoch 13/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9497 - loss: 0.1524 - val_accuracy: 0.9516 - val_loss: 0.1464
# Epoch 14/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9504 - loss: 0.1490 - val_accuracy: 0.9516 - val_loss: 0.1414
# Epoch 15/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9616 - loss: 0.1325 - val_accuracy: 0.9534 - val_loss: 0.1426
# Epoch 16/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9617 - loss: 0.1251 - val_accuracy: 0.9516 - val_loss: 0.1349
# Epoch 17/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9566 - loss: 0.1286 - val_accuracy: 0.9516 - val_loss: 0.1319
# Epoch 18/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9541 - loss: 0.1439 - val_accuracy: 0.9534 - val_loss: 0.1300
# Epoch 19/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9604 - loss: 0.1255 - val_accuracy: 0.9588 - val_loss: 0.1245
# Epoch 20/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9519 - loss: 0.1412 - val_accuracy: 0.9552 - val_loss: 0.1268
# Losses: 0.11550877243280411
# Accuracy: 0.9619526267051697
